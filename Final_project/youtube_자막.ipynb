# %% [markdown]
# <a href="https://colab.research.google.com/github/InTaewoo/multicampus-education/blob/main/Final_project/youtube_%EC%9E%90%EB%A7%89.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# --------- youtube__ 자막가져오기--

# %%
! pip install pytube
# Out:
# Collecting pytube
#   Downloading pytube-11.0.1-py3-none-any.whl (56 kB)
#      |████████████████████████████████| 56 kB 2.4 MB/s
# Installing collected packages: pytube
# Successfully installed pytube-11.0.1

# %%
from pytube import YouTube

# %%
video_url = 'https://www.youtube.com/watch?v=HqF46N5tZbE'
yt = YouTube(video_url)

# %%
print("[영상 제목]", yt.title)  # 영상제목
print("[영상 게시자]", yt.author) # 영상 게시자
print("[조회수]", yt.views)
print("[평균평점]", yt.rating) # 평균 평점
print("[영상길이(초)]", yt.length)
print("[연령제한여부]", yt.age_restricted)
print("[영상 설명]", yt.description) # 영상 설명
print("[썸네일URL]", yt.thumbnail_url) # 썸네일 url 주소
# Out:
# [영상 제목] '공동부유', 시진핑 주석 3연임을 향한 새로운 이데올로기 선언
# [영상 게시자] 슈카월드
# [조회수] 451043
# [평균평점] 4.8961406
# [영상길이(초)] 1143
# [연령제한여부] False
# [영상 설명] 어렵고 딱딱한 경제,시사,금융 이야기를
# 쉽고 유쾌하게 풀어내는
# 경제/시사/이슈/잡썰 토크방송입니다.
#
# #부의재분배 #공동부유
# [썸네일URL] https://i.ytimg.com/vi/HqF46N5tZbE/sddefault.jpg

# %%
yt.captions.all()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated function all (This object can be treated as a dictionary).
#   """Entry point for launching an IPython kernel.
# [<Caption lang="Korean (auto-generated)" code="a.ko">]

# %%
caption = yt.captions.get_by_language_code('a.ko')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   """Entry point for launching an IPython kernel.

# %%
caption.xml_captions
# Out:
# '<?xml version="1.0" encoding="utf-8" ?><timedtext format="3">\n<head>\n<ws id="0"/>\n<ws id="1" mh="2" ju="0" sd="3"/>\n<wp id="0"/>\n<wp id="1" ap="6" ah="20" av="100" rc="2" cc="40"/>\n</head>\n<body>\n<w t="0" id="1" wp="1" ws="1"/>\n<p t="0" d="3860" w="1"><s ac="232">아</s></p>\n<p t="280" d="3580" w="1" a="1">\n</p>\n<p t="290" d="3570" w="1">[음악]</p>\n<p t="4269" w="1" a="1">\n</p>\n<p t="4279" d="3801" w="1"><s ac="224">wr</s></p>\n<p t="7019" d="1061" w="1" a="1">\n</p>\n<p t="7029" d="3061" w="1"><s ac="126">자우</s><s t="181" ac="90"> 지배인</s><s t="480" ac="150"> 여긴</s><s t="660" ac="252"> 이런</s><s t="841" ac="249"> 얘기가</s></p>\n<p t="8070" d="2020" w="1" a="1">\n</p>\n<p t="8080" d="3960" w="1"><s ac="252">있습니다</s><s t="540" ac="205"> 지난주</s><s t="900" ac="167"> 3개를</s><s t="1559" ac="227"> 뜨겁게</s></p>\n<p t="10080" d="1960" w="1" a="1">\n</p>\n<p t="10090" d="4320" w="1"><s ac="252">만들었던</s><s t="600" ac="226"> 가장</s><s t="1110" ac="226"> 큰</s><s t="1350" ac="165"> 주제라고</s><s t="1740" ac="252"> 할</s><s t="1890" ac="255"> 수</s></p>\n<p t="12030" d="2380" w="1" a="1">\n</p>\n<p t="12040" d="5340" w="1"><s ac="239">있는데요</s><s t="599" ac="252"> 중국이</s><s t="1019" ac="252"> 시진핑</s><s t="1259" ac="237"> 주석이</s><s t="1829" ac="201"> 선언을</s></p>\n<p t="14400" d="2980" w="1" a="1">\n</p>\n<p t="14410" d="4920" w="1"><s ac="252">했죠</s><s t="240" ac="165"> 오라고</s><s t="780" ac="74"> 공동</s><s t="1619" ac="61"> 부유</s><s t="1980" ac="174"> 가</s><s t="2129" ac="239"> 필요하다</s></p>\n<p t="17370" d="1960" w="1" a="1">\n</p>\n<p t="17380" d="4110" w="1"><s ac="236">예</s><s t="120" ac="248"> 중국</s><s t="510" ac="229"> 주식</s><s t="780" ac="213"> 시장을</s><s t="1170" ac="239"> 흔들었고</s><s t="1530" ac="246"> 사실은</s></p>\n<p t="19320" d="2170" w="1" a="1">\n</p>\n<p t="19330" d="4200" w="1"><s ac="249">글로벌</s><s t="360" ac="247"> 전체를</s><s t="779" ac="229"> 흔들었던</s><s t="1170" ac="207"> 가장</s><s t="1560" ac="205"> 큰</s><s t="1920" ac="151"> 즉</s></p>\n<p t="21480" d="2050" w="1" a="1">\n</p>\n<p t="21490" d="3720" w="1"><s ac="205">미디어</s><s t="330" ac="208"> 홀로</s><s t="570" ac="204"> 기적에</s><s t="960" ac="252"> 가까울</s><s t="1500" ac="252"> 정도로</s><s t="1830" ac="252"> 큰</s></p>\n<p t="23520" d="1690" w="1" a="1">\n</p>\n<p t="23530" d="3870" w="1"><s ac="244">선언</s><s t="300" ac="255"> 이라고</s><s t="510" ac="220"> 할</s><s t="630" ac="220"> 수</s><s t="690" ac="252"> 있는데</s><s t="990" ac="237"> 중국이</s></p>\n<p t="25200" d="2200" w="1" a="1">\n</p>\n<p t="25210" d="4260" w="1"><s ac="233">공동</s><s t="450" ac="237"> 부유</s><s t="750" ac="252"> 가</s><s t="840" ac="221"> 필요하다</s><s t="1260" ac="252"> 부의</s><s t="1560" ac="236"> 재분배가</s></p>\n<p t="27390" d="2080" w="1" a="1">\n</p>\n<p t="27400" d="3690" w="1"><s ac="244">필요하다</s><s t="540" ac="252"> 라는</s><s t="719" ac="244"> 얘기를</s><s t="1020" ac="207"> 공식적으로</s><s t="1830" ac="243"> 팀</s></p>\n<p t="29460" d="1630" w="1" a="1">\n</p>\n<p t="29470" d="3240" w="1"><s ac="242">픽</s><s t="120" ac="210"> 추석이</s><s t="510" ac="220"> 얘기를</s><s t="990" ac="252"> 했습니다</s></p>\n<p t="31080" d="1630" w="1" a="1">\n</p>\n<p t="31090" d="4140" w="1"><s ac="238">이게</s><s t="120" ac="245"> 언제</s><s t="359" ac="243"> 나온</s><s t="570" ac="239"> 얘기냐</s><s t="810" ac="243"> 며</s><s t="900" ac="248"> 는</s><s t="1169" ac="248"> 중국이</s></p>\n<p t="32700" d="2530" w="1" a="1">\n</p>\n<p t="32710" d="4770" w="1"><s ac="82">8월초</s><s t="509" ac="207"> 의</s><s t="570" ac="155"> 베이</s><s t="1079" ac="167"> 다이어</s><s t="1650" ac="230"> 이라는걸</s></p>\n<p t="35220" d="2260" w="1" a="1">\n</p>\n<p t="35230" d="4230" w="1"><s ac="240">합니다</s><s t="480" ac="237"> 그래서</s><s t="690" ac="250"> 많이</s><s t="899" ac="248"> 들어보셨죠</s><s t="1620" ac="235"> 8i</s></p>\n<p t="37470" d="1990" w="1" a="1">\n</p>\n<p t="37480" d="3660" w="1"><s ac="224">허</s><s t="120" ac="224"> 가</s><s t="269" ac="239"> 뭐냐면은</s><s t="780" ac="255"> 중국</s><s t="1320" ac="249"> 휴양지에</s><s t="1769" ac="236"> 베이</s></p>\n<p t="39450" d="1690" w="1" a="1">\n</p>\n ...

# %%
ord('가')
# Out:
# 44032

# %%
import re

# %%
def cleanhtml(raw_html):
  cleanr = re.compile('<.*?>|&([a-z0-9]+|#[0-9]{1,6}|#x[0-9a-f]{1,6});')
  cleantext = re.sub(cleanr, '', raw_html)
  return cleantext

# %%
aa =str(caption.xml_captions)

# %%
text=str(cleanhtml(aa)).replace('\n','')

# %%
text
# Out:
# '아[음악]wr자우 지배인 여긴 이런 얘기가있습니다 지난주 3개를 뜨겁게만들었던 가장 큰 주제라고 할 수있는데요 중국이 시진핑 주석이 선언을했죠 오라고 공동 부유 가 필요하다예 중국 주식 시장을 흔들었고 사실은글로벌 전체를 흔들었던 가장 큰 즉미디어 홀로 기적에 가까울 정도로 큰선언 이라고 할 수 있는데 중국이공동 부유 가 필요하다 부의 재분배가필요하다 라는 얘기를 공식적으로 팀픽 추석이 얘기를 했습니다이게 언제 나온 얘기냐 며 는 중국이8월초 의 베이 다이어 이라는걸합니다 그래서 많이 들어보셨죠 8i허 가 뭐냐면은 중국 휴양지에 베이다이얼 않은 데가 있어요 여기에 8월초가 되면 은 중국의 위력 정치인사들 원로를 포함해서 현직 전현직정치인들이 다 보입니다 다 모여서피를 어떻게 비밀스럽게 하죠 공개하는게 아니라 자기 새끼를 모여서 뭔가스톡스 똑똑해요 중국 정부의 최대행사 중 하나고 뭐 전직 주소 현직투석 존재의 최고의 상무위원 죄다모여 갖고 비밀 합니다 거의 보름뭐래요 참고로 언제 열려 있는지 언제끝나는지 모릅니다 공식 일정을 안말해 주기 때문에 회의를 하는지어떻게 아냐 이렇게 알아요 시진핑주석을 포함한 공상 다 핵심인력7명이 갑자기 언론에서 모습이없어져요 7월 말에서 8월 초가 되면에 갑자기 4 없어져요 이 분들의보통 일거수일투족을 다 얘기 하잖아요저런데 중국 티스토리 다 그런데 시나통신은 데서는 의 성님이 못했고 우리모두 창녀 누가 뭐래도 모를 거야갑자기 말이 없어요 아 그러면 알아야됩니다 가졌구나 비밀히 알아보죠농가를 결정 하러 4 같이 가셔도달하는 걸 알면 되는데 중국의 베이다이얼 하는데가 여기죠 등 국 공 상당원들의 가장 윗분들의 별장이 있다고얘기하는 중국 건국의 아버지 아웃저도 의 여름 휴양지가 있다는 것이바로 여긴데 자금 이번 베인 라이어회의 설에 최대의 안건 최대 이슈어떤 얘기가 나올 거야 라고 사람들이기대 했냐며 는 이 거죠 과연 시진핑주석이 3년 임을 할 건지 아니면후계자 에 대한 언급이 나올 것인가3년후 모르겠다 세 번하고 네번째는안 할 것 같으니까 후계자가 누구이런 얘기가 나옵니다 보통 뭐 다음에누구라 던지다 놈 이런 얘기가나오는데 이거 최대 관심 이었는데오는 이렇게 생각하느냐 시진핑 주석이최고 권력자인 데코 누가 가서 뭐라고얘기를 하냐 중국은 생각보다 파벌정치가 굉장히 강하다 글 황제 비슷한구석이 있지만 그 마음대로 못하고이런 파벌 들이 있기 때문에 그 파벌들의 이해관계를 다 들어왔고 조정을하는 거죠 그건 밀실에 가서 지금베이 다이어 에 가서 조정을 하는거죠 그 전에 이미 헌법 개정 해놨고쓰지 후계자가 나올지 실제로 3년 임사임을 할지를 얘기를 했겠죠 우리는모르지만 얘기를 하고 결론이나왔을텐데그리고 나와서 왜 4회가 끝나고드디어 주석이나 이제 상무위원 들이보였을 때 과연 후 개재된 언급을할까 없었죠 언급이 없었어요 언급이없고 공동 비유에 대한 얘기가나왔어요 그 얘기 닉슨 아 아 어3년 힘은 거의 되는것 같다 로사람들 생각을 했죠 후 개재 대해언급이 있어야 뭐 자연님 승려임을뭐가 있을 텐데 그 얘기가 없고 공동주요 로 우린 앞으로 어떻게 사회를가야겠다는 얘기를 나오는거 보니까아무래도 상영을 할 거 같다는 생각을많이 하고 자 그러면은 공부에 대한내용을 조금더 보면 자 8월 18일날베다 2회가 끝난 다음에 나오자마자중국 재경 위원회에서 10핀 주석이공동 2위를 제작했습니다 공동구 의내용이 뭐냐 궁동 부유 는 사회 귀에본질적인 요구다 중국식 현대화의중요한 특징이다 공동 부위를 촉진해야된다 알겠어 그럼 구체적인 내용은여기서부터 좀 무서워 지는데 과도한소득을 합리적으로 조정해야 된다부유층과 기업이 차지하는 몫을 줄여야한다 아 중국의 기법들을 기자 배당을강진 할 수 있습니다 실제 귀가나오고 있어요 배당을 강제로 만들수도 있습니다 얘기가 나오고 있고자사주 매입 이런거 관계를 시킬 수도있죠 인던 상승을 법 에 저장할 수도있어요 실제 그런 얘기 나올 수 뒤에조금있다 보여 될텐데 과 단 소득을조정하고 부유층과 게임이 차지하는것을 줄여 갖고 공동으로 가야 된다이걸 해야 뭘 할 수 있다 당해 에장기집권을 일어 낼 수 있다 당의장기집권 이란 말은 한마디로 다른표현으로 3년이 잘생긴 됩니까 뭐이런거 비싸지 않은가 라고 생각을하지만 그렇지 안기지 꼬는 이런 애기이면 방법론을 얘기했고 후계자의 길을한 게 아니었죠 그래서 실제로 올해초부터 중국에서 가장 잘 사는 동네도저장성을 공동 부유 시범적으로 건설을했어요 여긴 이미 소득 재분배 초고수입자 조절 기업 인센티브 작렬하고쓰고 강 지겠죠 사용하는 장녀한다던지 해당 제를 강화 한다던지임금 상승을 어느정도 경부가 뭐가야되는 주겠죠 쌈 프로 5%넣으시고 최저임금제 를 강 한다던지한식으로 0 동부 시범지구 를건설했고 저장 성의 체험적으로 한이유는 간단하죠 디핑 주석이 저장 성5기 주시죠 영성이 미는 됩니다중국에서 가장 잘사는 돈이기 때문에여기서 이제 먼저 시도할 수 있고작을 공동 부유 내용을 좀 보면기업들이 기절을 했죠 이것때문에 왜냐k 는 과도한 수입 사치 최저임금과도한 수입금지 모금 지정도 어떤제재를 하겠죠 사치 제재하고 최저임금올리도록 노력 알고 임금 상승이같은거 만들 꺼고 기억 같은 독점2기 줘야 될 거고 가격 기제가 될프라이스 규제가 들어가고 기업들이문어발 받는거 영역 규제가 들어가고요즘에는 디트 b 조 되겟죠 한마디로대형 it 플랫폼은 날라 같구요추측컨대 달랐고 의약품 다 줬어요바이오 가 엄청 빠졌는데 프라이스 를조절 한다는 말은 의미 한테 약을주는데 내가 약을 어떻게 아까 이렇게비싸게 받을 수 있어 약가 2녀를들어가죠 약 값을 비싸게 못하기때문에 주가가 데려와 4 교육규제당연하겠지만 를 보여 드렸듯이 90g빠졌구요 대한 복종 플랫폼 하니까내려간 데다가 요즘에 뜨는거 늦는데란 말씀이 어떤 부동산 규제부동산가격 많이 올라서 문제가 되니까중국 대표 부동산 재벌인 홍 다가매탄 내 약 면담을 했습니다 이렇게파로 20 인데 아마 어떤 관영 매체에서 이런 얘기에 살자 라는 걸보니까 중국 8 부동산세 가 나올 수있겠죠 지금 적절한 시계 재산세라던지 뭔지 몰라도 중국 만에 그부동산의 가격에 매기는 책임이 나타날가능성이 굉장히 높고 아니면 실제로소유권을 제안 한다던지 그러다 보니까중국 자 분들이 해외부동산 으로 많이빠지죠 우리나라에서도 많이 사고미국에서도 많이 사고 부주의 에서도많이 사고 부동산 많이 빠지는데 초뉴스가 나오자 마자 여러분도보셨겠지만 사치품 기업들 명품기업들이 박살이 났습니다 예 보통중국 매출이 야 3분의 1은 중국에서10만 1 4 제품 기업들은 명품녀들을 루이뷔통 700번 어떤게 n일주일도 안되서 16% 라임의 날라같구요 가장 많이 날라오는 게 구치죠 28대 예뻐요 우리나라 삼성 는양반입니다 우리나라 8만 이전해서76,000원 가니까 와 나라 힘든데여기는 구찌는 이게 뭡니까예 이렇게 가다가 완전히 직격탄 말씀20% 이상 빠졌고 물론 구찌가 길게보면 굉장히 많이 올랐죠 중국발호황을 누려 왔고 엄청나게 올랐다가위해서 조정 받는 거긴 하지만 굉장히가파르게 조정을 받았고 아까 지겠지만사치품 일하게 하는 이런 수주 마우타이즈 중국 최대의 기어 마우 타이주 이런데는 굉장히 많이 밀렸고 홍콩지수 자체가 굉장히 많이 밀리면서우리나라 코스피 해도 좋아 교양을 쪼쪽 지수 자체가 뭐 고점대비 20번지상 밀리 누명을 받고 쥬스가 나온다음에 잽싸게 반응하는 기업도 있었죠텐센트는예 우리는 구조 원을 내겠다 들어온공동 우유 프로젝트 우리가 앞장서서했습니다 아 텐센트가 나 같구요이렇게 얘기했습니다 사회에서 얻은것당연히 사회에 환원해야 되지않겠습니까훌륭한 친구들입니다 눈치가 빨라 제발사회에서 얻은건 우리는 사회에환원하겠다고 물론 주가 날라가고있지만 실제로 구조 원짜리 징플레이트를 내 색에 따라 는 발표를했고요 결론적으로 중국의 베이 다이어해인 결과 신빙성이 장기집권 카드용나온 것 같고 공동 부유 라는키워드로 어떤 자기 3년여 사용 동안이데올로기를 제시 했자나 그 중 9개파간 권력 조절에 결과라고 볼 수있는데 재미있는게 중국이 계파간 권력조절을 한다는게 잘 모르시는 분들이서 잠깐만 설명을 드리면 예전에 등국에 건국의 아버지 라고 쪼 도모택동 우리나라 많은 뭐 택도 2 꼭내 전 승리를 거두고 중국을 만들었죠2분이 쪼 ...
