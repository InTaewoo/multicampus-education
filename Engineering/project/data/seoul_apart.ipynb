# %%
cd ..
# Out:
# /Users/intaewoo

# %%
! pwd
# Out:
# /Users/intaewoo/Downloads

# %%
cd Desktop/project/DE Pj
# Out:
# /Users/intaewoo/Desktop/project/DE Pj

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import pandas_profiling as pp
import seaborn as sns

# %matplotlib inline
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('apart.csv')
df
# Out:
#                   시군구     번지             단지명  전용면적(㎡)    계약년월  계약일  \
# 0       서울특별시 강남구 개포동  655-2  개포2차현대아파트(220)    77.75  201501   11
# 1       서울특별시 강남구 개포동  658-1  개포6차우성아파트1동~8동    79.97  201501   29
# 2       서울특별시 강남구 개포동    141        개포주공 1단지    50.64  201501    5
# 3       서울특별시 강남구 개포동    141        개포주공 1단지    42.55  201501    7
# 4       서울특별시 강남구 개포동    141        개포주공 1단지    50.38  201501    7
# ...               ...    ...             ...      ...     ...  ...
# 603053  서울특별시 중랑구 중화동    450            한신1차    59.76  202106   24
# 603054  서울특별시 중랑구 중화동    450            한신1차    50.37  202106   25
# 603055  서울특별시 중랑구 중화동    450            한신1차    50.37  202106   26
# 603056  서울특별시 중랑구 중화동    450            한신1차    59.76  202106   26
# 603057  서울특별시 중랑구 중화동    450            한신1차    84.69  202106   30
#
#               거래금액(만원)  층  건축년도      도로명  해제사유발생일
# 0               60,000  5  1988  언주로 103      NaN
# 1               73,000  5  1987    언주로 3      NaN
# 2               83,000  1  1982  개포로 310      NaN
# 3               70,000  1  1982  개포로 310      NaN
# 4               83,000  5  1982  개포로 310      NaN
# ...                ... ..   ...      ...      ...
# 603053          66,000  2  1997  동일로 752      NaN
# 603054          62,000  3  1997  동일로 752      NaN
# 603055          64,500  5  1997  동일로 752      NaN
# 603056          66,000  1  1997  동일로 752      NaN
# 603057          85,000  8  1997  동일로 752      NaN
#
# [603058 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 603058 entries, 0 to 603057
# Data columns (total 11 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   시군구       603058 non-null  object
#  1   번지        602843 non-null  object
#  2   단지명       603058 non-null  object
#  3   전용면적(㎡)   603058 non-null  float64
#  4   계약년월      603058 non-null  int64
#  5   계약일       603058 non-null  int64
#  6   거래금액(만원)  603058 non-null  object
#  7   층         603058 non-null  int64
#  8   건축년도      603058 non-null  int64
#  9   도로명       603058 non-null  object
#  10  해제사유발생일   3709 non-null    float64
# dtypes: float64(2), int64(4), object(5)
# memory usage: 50.6+ MB

# %%
df.describe()

# %%
df['아파트크기']=0
df
# Out:
#                   시군구     번지             단지명  전용면적(㎡)    계약년월  계약일  \
# 0       서울특별시 강남구 개포동  655-2  개포2차현대아파트(220)    77.75  201501   11
# 1       서울특별시 강남구 개포동  658-1  개포6차우성아파트1동~8동    79.97  201501   29
# 2       서울특별시 강남구 개포동    141        개포주공 1단지    50.64  201501    5
# 3       서울특별시 강남구 개포동    141        개포주공 1단지    42.55  201501    7
# 4       서울특별시 강남구 개포동    141        개포주공 1단지    50.38  201501    7
# ...               ...    ...             ...      ...     ...  ...
# 603053  서울특별시 중랑구 중화동    450            한신1차    59.76  202106   24
# 603054  서울특별시 중랑구 중화동    450            한신1차    50.37  202106   25
# 603055  서울특별시 중랑구 중화동    450            한신1차    50.37  202106   26
# 603056  서울특별시 중랑구 중화동    450            한신1차    59.76  202106   26
# 603057  서울특별시 중랑구 중화동    450            한신1차    84.69  202106   30
#
#               거래금액(만원)  층  건축년도      도로명  해제사유발생일  아파트크기
# 0               60,000  5  1988  언주로 103      NaN      0
# 1               73,000  5  1987    언주로 3      NaN      0
# 2               83,000  1  1982  개포로 310      NaN      0
# 3               70,000  1  1982  개포로 310      NaN      0
# 4               83,000  5  1982  개포로 310      NaN      0
# ...                ... ..   ...      ...      ...    ...
# 603053          66,000  2  1997  동일로 752      NaN      0
# 603054          62,000  3  1997  동일로 752      NaN      0
# 603055          64,500  5  1997  동일로 752      NaN      0
# 603056          66,000  1  1997  동일로 752      NaN      0
# 603057          85,000  8  1997  동일로 752      NaN      0
#
# [603058 rows x 12 columns]

# %%
apt_len = len(df.index)
apt_len
# Out:
# 603058

# %%
for i in range(0,603058):
    if df['전용면적(㎡)'][i] <= 60:
        df['아파트크기'][i] ='소형'
    elif df['전용면적(㎡)'][i] > 85:
        df['아파트크기'][i]='대형'
    else :
        df['아파트크기'][i] = '중형'
# Out:
# /opt/anaconda3/envs/multi/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /opt/anaconda3/envs/multi/lib/python3.7/site-packages/pandas/core/indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# /opt/anaconda3/envs/multi/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/envs/multi/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
df
# Out:
#                   시군구     번지             단지명  전용면적(㎡)  계약년월  계약일  \
# 0       서울특별시 강남구 개포동  655-2  개포2차현대아파트(220)    77.75    14   11
# 1       서울특별시 강남구 개포동  658-1  개포6차우성아파트1동~8동    79.97    38   29
# 2       서울특별시 강남구 개포동    141        개포주공 1단지    50.64     6    5
# 3       서울특별시 강남구 개포동    141        개포주공 1단지    42.55    13    7
# 4       서울특별시 강남구 개포동    141        개포주공 1단지    50.38    13    7
# ...               ...    ...             ...      ...   ...  ...
# 603053  서울특별시 중랑구 중화동    450            한신1차    59.76    24   24
# 603054  서울특별시 중랑구 중화동    450            한신1차    50.37    25   25
# 603055  서울특별시 중랑구 중화동    450            한신1차    50.37    34   26
# 603056  서울특별시 중랑구 중화동    450            한신1차    59.76    34   26
# 603057  서울특별시 중랑구 중화동    450            한신1차    84.69    56   30
#
#               거래금액(만원)  층  건축년도      도로명  해제사유발생일 아파트크기
# 0               60,000  5  1988  언주로 103      NaN    중형
# 1               73,000  5  1987    언주로 3      NaN    중형
# 2               83,000  1  1982  개포로 310      NaN    소형
# 3               70,000  1  1982  개포로 310      NaN    소형
# 4               83,000  5  1982  개포로 310      NaN    소형
# ...                ... ..   ...      ...      ...   ...
# 603053          66,000  2  1997  동일로 752      NaN    소형
# 603054          62,000  3  1997  동일로 752      NaN    소형
# 603055          64,500  5  1997  동일로 752      NaN    소형
# 603056          66,000  1  1997  동일로 752      NaN    소형
# 603057          85,000  8  1997  동일로 752      NaN    중형
#
# [603058 rows x 12 columns]

# %%
df['아파트크기'].value_counts()

# %%
df['']
# Out:
#                   시군구     번지             단지명  전용면적(㎡)  계약년월  계약일  \
# 0       서울특별시 강남구 개포동  655-2  개포2차현대아파트(220)    77.75    14   11
# 1       서울특별시 강남구 개포동  658-1  개포6차우성아파트1동~8동    79.97    38   29
# 2       서울특별시 강남구 개포동    141        개포주공 1단지    50.64     6    5
# 3       서울특별시 강남구 개포동    141        개포주공 1단지    42.55    13    7
# 4       서울특별시 강남구 개포동    141        개포주공 1단지    50.38    13    7
# ...               ...    ...             ...      ...   ...  ...
# 603053  서울특별시 중랑구 중화동    450            한신1차    59.76    24   24
# 603054  서울특별시 중랑구 중화동    450            한신1차    50.37    25   25
# 603055  서울특별시 중랑구 중화동    450            한신1차    50.37    34   26
# 603056  서울특별시 중랑구 중화동    450            한신1차    59.76    34   26
# 603057  서울특별시 중랑구 중화동    450            한신1차    84.69    56   30
#
#               거래금액(만원)  층  건축년도      도로명  해제사유발생일 아파트크기
# 0               60,000  5  1988  언주로 103      NaN    중형
# 1               73,000  5  1987    언주로 3      NaN    중형
# 2               83,000  1  1982  개포로 310      NaN    소형
# 3               70,000  1  1982  개포로 310      NaN    소형
# 4               83,000  5  1982  개포로 310      NaN    소형
# ...                ... ..   ...      ...      ...   ...
# 603053          66,000  2  1997  동일로 752      NaN    소형
# 603054          62,000  3  1997  동일로 752      NaN    소형
# 603055          64,500  5  1997  동일로 752      NaN    소형
# 603056          66,000  1  1997  동일로 752      NaN    소형
# 603057          85,000  8  1997  동일로 752      NaN    중형
#
# [603058 rows x 12 columns]

# %%
pd.to_datetime(df['계약년월'])
# Out:
# 0        1970-01-01 00:00:00.000201501
# 1        1970-01-01 00:00:00.000201501
# 2        1970-01-01 00:00:00.000201501
# 3        1970-01-01 00:00:00.000201501
# 4        1970-01-01 00:00:00.000201501
#                       ...
# 603053   1970-01-01 00:00:00.000202106
# 603054   1970-01-01 00:00:00.000202106
# 603055   1970-01-01 00:00:00.000202106
# 603056   1970-01-01 00:00:00.000202106
# 603057   1970-01-01 00:00:00.000202106
# Name: 계약년월, Length: 603058, dtype: datetime64[ns]

# %%
df[df['시군구'].str.startswith(2015)].head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-99-8a0d0912c693> in <module>
# ----> 1 df[df['전용면적(㎡)'].str.startswith(2015)].head()
#
# /opt/anaconda3/envs/multi/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5459             or name in self._accessors
#    5460         ):
# -> 5461             return object.__getattribute__(self, name)
#    5462         else:
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# /opt/anaconda3/envs/multi/lib/python3.7/site-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     178             # we're accessing the attribute of the class, i.e., Dataset.geo
#     179             return self._accessor
# --> 180         accessor_obj = self._accessor(obj)
#     181         # Replace the property with the accessor object. Inspired by:
#     182         # https://www.pydanny.com/cached-property.html
#
# /opt/anaconda3/envs/multi/lib/python3.7/site-packages/pandas/core/strings/accessor.py in __init__(self, data)
#     152         from pandas.core.arrays.string_ import StringDtype
#     153
# --> 154         self._inferred_dtype = self._validate(data)
#     155         self._is_categorical = is_categorical_dtype(data.dtype)
#     156         self._is_string = isinstance(data.dtype, StringDtype)
#
# /opt/anaconda3/envs/multi/lib/python3.7/site-packages/pandas/core/strings/accessor.py in _validate(data)
#     215
#     216         if inferred_dtype not in allowed_types:
# --> 217             raise AttributeError("Can only use .str accessor with string values!")
#     218         return inferred_dtype
#     219
#
# AttributeError: Can only use .str accessor with string values!

# %%
df[df['계약년월'][:4]==2015]
# Out:
# /opt/anaconda3/envs/multi/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# <ipython-input-89-bce4e4463641> in <module>
# ----> 1 df[df['계약년월'][:4]==2015]
#
# /opt/anaconda3/envs/multi/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3013         # Do we have a (boolean) 1d indexer?
#    3014         if com.is_bool_indexer(key):
# -> 3015             return self._getitem_bool_array(key)
#    3016
#    3017         # We are left with two options: a single key, and a collection of keys,
#
# /opt/anaconda3/envs/multi/lib/python3.7/site-packages/pandas/core/frame.py in _getitem_bool_array(self, key)
#    3066         # check_bool_indexer will throw exception if Series key cannot
#    3067         # be reindexed to match DataFrame rows
# -> 3068         key = check_bool_indexer(self.index, key)
#    3069         indexer = key.nonzero()[0]
#    3070         return self._take_with_is_copy(indexer, axis=0)
#
# /opt/anaconda3/envs/multi/lib/python3.7/site-packages/pandas/core/indexing.py in check_bool_indexer(index, key)
#    2268         if mask.any():
#    2269             raise IndexingError(
# -> 2270                 "Unalignable boolean Series provided as "
#    2271                 "indexer (index of the boolean Series and of "
#    2272                 "the indexed object do not match)."
#
# IndexingError: Unalignable boolean Series provided as indexer (index of the boolean Series and of the indexed object do not match).
